# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
from google.colab import drive
drive.mount('/content/drice/')
# Out:
# Drive already mounted at /content/drice/; to attempt to forcibly remount, call drive.mount("/content/drice/", force_remount=True).

# %%
df=pd.read_csv('/content/drice/MyDrive/laptop_price_prediction/laptop_data.csv')

# %%
df.sample()
# Out:
#      Unnamed: 0 Company  TypeName  ...       OpSys Weight     Price
# 362         362  Lenovo  Notebook  ...  Windows 10  2.8kg  38308.32
#
# [1 rows x 12 columns]

# %%
df.drop(columns=['Unnamed: 0'],inplace=True)

# %%
df.sample()
# Out:
#    Company  TypeName  Inches  ...  OpSys Weight     Price
# 40    Asus  Notebook    15.6  ...  Linux    2kg  20725.92
#
# [1 rows x 11 columns]

# %%
df.shape
# Out:
# (1303, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   object
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   object
#  10  Price             1303 non-null   float64
# dtypes: float64(2), object(9)
# memory usage: 112.1+ KB

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1298     True
# 1299     True
# 1300     True
# 1301     True
# 1302     True
# Length: 1303, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 29

# %%
df.duplicated().sum()
# Out:
# 29

# %%
df[df.duplicated()==True]
# Out:
#      Company            TypeName  Inches  ...       OpSys  Weight       Price
# 1274    Asus            Notebook    15.6  ...  Windows 10   2.2kg  19660.3200
# 1275    Asus           Ultrabook    13.3  ...  Windows 10   1.2kg  38841.1200
# 1276    Dell            Notebook    15.6  ...  Windows 10   2.3kg  24455.5200
# 1277    Acer            Notebook    15.6  ...       Linux   2.4kg  15397.9200
# 1278    Dell            Notebook    15.6  ...  Windows 10  2.20kg  20193.1200
# 1279  Lenovo            Notebook    15.6  ...  Windows 10   2.6kg  47898.7200
# 1280      HP            Notebook    15.6  ...  Windows 10  2.04kg  29303.4672
# 1281    Dell            Notebook    15.6  ...       Linux   2.3kg  42943.1472
# 1282      HP             Netbook    11.6  ...  Windows 10  1.17kg  11135.5200
# 1283    Asus            Notebook    15.6  ...  Windows 10   2.2kg  38378.6496
# 1284  Lenovo  2 in 1 Convertible    14.0  ...  Windows 10   1.8kg  33992.6400
# ...

# %%
# Duplicated Row Remove 
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (1274, 11)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
df.head()
# Out:
#   Company   TypeName  Inches  ...  OpSys  Weight        Price
# 0   Apple  Ultrabook    13.3  ...  macOS  1.37kg   71378.6832
# 1   Apple  Ultrabook    13.3  ...  macOS  1.34kg   47895.5232
# 2      HP   Notebook    15.6  ...  No OS  1.86kg   30636.0000
# 3   Apple  Ultrabook    15.4  ...  macOS  1.83kg  135195.3360
# 4   Apple  Ultrabook    13.3  ...  macOS  1.37kg   96095.8080
#
# [5 rows x 11 columns]

# %%
# GB & kg Remove---
df['Ram']=df['Ram'].str.replace('GB',"")
df['Weight']=df['Weight'].str.replace('kg','')

# %%
df.head()
# Out:
#   Company   TypeName  Inches  ...  OpSys Weight        Price
# 0   Apple  Ultrabook    13.3  ...  macOS   1.37   71378.6832
# 1   Apple  Ultrabook    13.3  ...  macOS   1.34   47895.5232
# 2      HP   Notebook    15.6  ...  No OS   1.86   30636.0000
# 3   Apple  Ultrabook    15.4  ...  macOS   1.83  135195.3360
# 4   Apple  Ultrabook    13.3  ...  macOS   1.37   96095.8080
#
# [5 rows x 11 columns]

# %%
df['Ram'].value_counts()
# Out:
# 8     613
# 4     366
# 16    198
# 6      35
# 12     25
# 32     17
# 2      16
# 24      3
# 64      1
# Name: Ram, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1274 entries, 0 to 1273
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1274 non-null   object
#  1   TypeName          1274 non-null   object
#  2   Inches            1274 non-null   float64
#  3   ScreenResolution  1274 non-null   object
#  4   Cpu               1274 non-null   object
#  5   Ram               1274 non-null   object
#  6   Memory            1274 non-null   object
#  7   Gpu               1274 non-null   object
#  8   OpSys             1274 non-null   object
#  9   Weight            1274 non-null   object
#  10  Price             1274 non-null   float64
# dtypes: float64(2), object(9)
# memory usage: 119.4+ KB

# %%
# Ram column Type Change Object to Integer
# Weight Columns Type Change Object to Floating 
df['Ram']=df['Ram'].astype('int32')
df['Weight']=df['Weight'].astype('float32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1274 entries, 0 to 1273
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1274 non-null   object
#  1   TypeName          1274 non-null   object
#  2   Inches            1274 non-null   float64
#  3   ScreenResolution  1274 non-null   object
#  4   Cpu               1274 non-null   object
#  5   Ram               1274 non-null   int32
#  6   Memory            1274 non-null   object
#  7   Gpu               1274 non-null   object
#  8   OpSys             1274 non-null   object
#  9   Weight            1274 non-null   float32
#  10  Price             1274 non-null   float64
# dtypes: float32(1), float64(2), int32(1), object(7)
# memory usage: 109.5+ KB

# %%
sn.distplot(df['Price'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df['Company'].value_counts().plot(kind='bar')

# %%
sn.barplot(x=df['Company'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df['TypeName'].value_counts().plot(kind='bar')

# %%
sn.barplot(x=df['TypeName'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sn.scatterplot(x=df['Ram'],y=df['Price'])

# %%
sn.distplot(df['Inches'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df.head()
# Out:
#   Company   TypeName  Inches  ...  OpSys Weight        Price
# 0   Apple  Ultrabook    13.3  ...  macOS   1.37   71378.6832
# 1   Apple  Ultrabook    13.3  ...  macOS   1.34   47895.5232
# 2      HP   Notebook    15.6  ...  No OS   1.86   30636.0000
# 3   Apple  Ultrabook    15.4  ...  macOS   1.83  135195.3360
# 4   Apple  Ultrabook    13.3  ...  macOS   1.37   96095.8080
#
# [5 rows x 11 columns]

# %%
df['Company'].value_counts()
# Out:
# Dell         291
# Lenovo       289
# HP           268
# Asus         151
# Acer         101
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Razer          7
# Mediacom       7
# Microsoft      6
# Xiaomi         4
# Vero           4
# Chuwi          3
# Google         3
# Fujitsu        3
# LG             3
# Huawei         2
# Name: Company, dtype: int64

# %%
df['ScreenResolution'].value_counts()
# Out:
# Full HD 1920x1080                                505
# 1366x768                                         262
# IPS Panel Full HD 1920x1080                      226
# IPS Panel Full HD / Touchscreen 1920x1080         51
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# Touchscreen 2256x1504                              6
# IPS Panel Touchscreen 2560x1440                    5
# ...

# %%
df['Touchscreen']=df['ScreenResolution'].apply(lambda x : 1 if 'Touchscreen' in x else 0)

# %%
df.head()
# Out:
#   Company   TypeName  Inches  ... Weight        Price  Touchscreen
# 0   Apple  Ultrabook    13.3  ...   1.37   71378.6832            0
# 1   Apple  Ultrabook    13.3  ...   1.34   47895.5232            0
# 2      HP   Notebook    15.6  ...   1.86   30636.0000            0
# 3   Apple  Ultrabook    15.4  ...   1.83  135195.3360            0
# 4   Apple  Ultrabook    13.3  ...   1.37   96095.8080            0
#
# [5 rows x 12 columns]

# %%
df.sample(5)
# Out:
#      Company   TypeName  Inches  ... Weight      Price  Touchscreen
# 439     Asus   Notebook    15.6  ...   2.00   29783.52            0
# 864     Dell  Ultrabook    13.3  ...   1.29  119347.20            1
# 578      MSI     Gaming    17.3  ...   4.14  145401.12            0
# 861       HP   Notebook    15.6  ...   1.84   71874.72            0
# 655  Toshiba   Notebook    15.6  ...   2.00   56689.92            0
#
# [5 rows x 12 columns]

# %%
df['Touchscreen'].value_counts().plot(kind='bar')

# %%
df['Touchscreen'].value_counts()
# Out:
# 0    1086
# 1     188
# Name: Touchscreen, dtype: int64

# %%
sn.barplot(x=df['Touchscreen'],y=df['Price'])

# %%
df['IPS']=df['ScreenResolution'].apply(lambda x: 1 if 'IPS' in x else 0)

# %%
df.sample(5)
# Out:
#      Company   TypeName  Inches  ...       Price Touchscreen  IPS
# 151     Dell     Gaming    15.6  ...  47898.7200           0    0
# 117     Dell   Notebook    15.6  ...  60223.9824           0    1
# 523       HP   Notebook    15.6  ...  36709.9200           0    0
# 996       HP  Ultrabook    13.3  ...  71874.7200           1    1
# 1085      HP   Notebook    14.0  ...  54931.1472           0    0
#
# [5 rows x 13 columns]

# %%
sn.barplot(x=df['IPS'],y=df['Price'])

# %%
new=df['ScreenResolution'].str.split('x',n=1,expand=True)

# %%
new
# Out:
#                                           0     1
# 0             IPS Panel Retina Display 2560  1600
# 1                                      1440   900
# 2                              Full HD 1920  1080
# 3             IPS Panel Retina Display 2880  1800
# 4             IPS Panel Retina Display 2560  1600
# ...                                     ...   ...
# 1269                                   1366   768
# 1270   IPS Panel Full HD / Touchscreen 1920  1080
# 1271  IPS Panel Quad HD+ / Touchscreen 3200  1800
# 1272                                   1366   768
# 1273                                   1366   768
#
# [1274 rows x 2 columns]

# %%
df['X_res']=new[0]
df['Y_res']=new[1]

# %%
df.head(5)
# Out:
#   Company   TypeName  Inches  ... IPS                          X_res  Y_res
# 0   Apple  Ultrabook    13.3  ...   1  IPS Panel Retina Display 2560   1600
# 1   Apple  Ultrabook    13.3  ...   0                           1440    900
# 2      HP   Notebook    15.6  ...   0                   Full HD 1920   1080
# 3   Apple  Ultrabook    15.4  ...   1  IPS Panel Retina Display 2880   1800
# 4   Apple  Ultrabook    13.3  ...   1  IPS Panel Retina Display 2560   1600
#
# [5 rows x 15 columns]

# %%
df['X_res']=df['X_res'].str.replace(',','').str.findall(r'(\d+\.?\d+)').apply(lambda x:x[0])

# %%
df.sample(2)
# Out:
#     Company            TypeName  Inches  ... IPS X_res  Y_res
# 848      HP  2 in 1 Convertible    13.3  ...   0  1920   1080
# 381  Lenovo            Notebook    15.6  ...   0  1920   1080
#
# [2 rows x 15 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1274 entries, 0 to 1273
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1274 non-null   object
#  1   TypeName          1274 non-null   object
#  2   Inches            1274 non-null   float64
#  3   ScreenResolution  1274 non-null   object
#  4   Cpu               1274 non-null   object
#  5   Ram               1274 non-null   int32
#  6   Memory            1274 non-null   object
#  7   Gpu               1274 non-null   object
#  8   OpSys             1274 non-null   object
#  9   Weight            1274 non-null   float32
#  10  Price             1274 non-null   float64
#  11  Touchscreen       1274 non-null   int64
#  12  IPS               1274 non-null   int64
#  13  X_res             1274 non-null   object
#  14  Y_res             1274 non-null   object
# dtypes: float32(1), float64(2), int32(1), int64(2), object(9)
# ...

# %%
df['X_res']=df['X_res'].astype('int32')
df['Y_res']=df['Y_res'].astype('int32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1274 entries, 0 to 1273
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1274 non-null   object
#  1   TypeName          1274 non-null   object
#  2   Inches            1274 non-null   float64
#  3   ScreenResolution  1274 non-null   object
#  4   Cpu               1274 non-null   object
#  5   Ram               1274 non-null   int32
#  6   Memory            1274 non-null   object
#  7   Gpu               1274 non-null   object
#  8   OpSys             1274 non-null   object
#  9   Weight            1274 non-null   float32
#  10  Price             1274 non-null   float64
#  11  Touchscreen       1274 non-null   int64
#  12  IPS               1274 non-null   int64
#  13  X_res             1274 non-null   int32
#  14  Y_res             1274 non-null   int32
# dtypes: float32(1), float64(2), int32(3), int64(2), object(7)
# ...

# %%
df.corr()['Price']
# Out:
# Inches         0.066990
# Ram            0.740106
# Weight         0.212192
# Price          1.000000
# Touchscreen    0.188631
# IPS            0.250358
# X_res          0.552074
# Y_res          0.548111
# Name: Price, dtype: float64

# %%
df['ppi'] = (((df['X_res']**2) + (df['Y_res']**2))**0.5/df['Inches']).astype('float')

# %%
df.corr()['Price']
# Out:
# Inches         0.066990
# Ram            0.740106
# Weight         0.212192
# Price          1.000000
# Touchscreen    0.188631
# IPS            0.250358
# X_res          0.552074
# Y_res          0.548111
# ppi            0.469539
# Name: Price, dtype: float64

# %%
df.drop(columns=['ScreenResolution'],inplace=True)

# %%
df.sample(1)
# Out:
#      Company  TypeName  Inches  ... X_res  Y_res         ppi
# 1003      HP  Notebook    14.0  ...  1366    768  111.935204
#
# [1 rows x 15 columns]

# %%
df.drop(columns=['Inches','X_res','Y_res'],inplace=True)

# %%
df.head(5)
# Out:
#   Company   TypeName                         Cpu  ...  Touchscreen IPS         ppi
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz  ...            0   1  226.983005
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz  ...            0   0  127.677940
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz  ...            0   0  141.211998
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz  ...            0   1  220.534624
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz  ...            0   1  226.983005
#
# [5 rows x 12 columns]

# %%
df['Cpu'].value_counts()
# Out:
# Intel Core i5 7200U 2.5GHz     190
# Intel Core i7 7700HQ 2.8GHz    146
# Intel Core i7 7500U 2.7GHz     132
# Intel Core i7 8550U 1.8GHz      73
# Intel Core i5 8250U 1.6GHz      72
#                               ...
# Intel Core M M3-6Y30 0.9GHz      1
# AMD A9-Series 9420 2.9GHz        1
# Intel Core i5 2.9GHz             1
# AMD A6-Series 7310 2GHz          1
# AMD A9-Series 9410 2.9GHz        1
# Name: Cpu, Length: 118, dtype: int64

# %%
df['Cpu Name']=df['Cpu'].apply(lambda x :" ".join(x.split()[:3]))

# %%
df['Cpu Name'].value_counts()
# Out:
# Intel Core i7               515
# Intel Core i5               423
# Intel Core i3               134
# Intel Celeron Dual           69
# Intel Pentium Quad           27
# Intel Core M                 17
# AMD A9-Series 9420           12
# AMD A6-Series 9220            8
# Intel Celeron Quad            8
# AMD A12-Series 9720P          7
# Intel Atom x5-Z8350           5
# Intel Atom x5-Z8550           4
# AMD A8-Series 7410            4
# Intel Pentium Dual            3
# AMD Ryzen 1700                3
# Intel Atom X5-Z8350           2
# Intel Xeon E3-1535M           2
# AMD A9-Series A9-9420         2
# AMD E-Series 7110             2
# AMD A10-Series 9620P          2
# AMD A10-Series 9600P          2
# AMD A6-Series A6-9220         2
# Intel Xeon E3-1505M           2
# AMD E-Series E2-9000e         2
# AMD A10-Series A10-9620P      2
# Intel Atom x5-Z8300           1
# AMD E-Series 9000             1
# Samsung Cortex A72&A53        1
# AMD FX 8800P                  1
# ...

# %%
def fache_processor(txt):
  if txt =='Intel Core i7' or txt=='Intel Core i5' or txt =='Intel Core i3':
    return txt
  elif 'Intel' in txt:
    return 'Other Intel Processor'
  else:
    return "AMD"

# %%
print(fache_processor('Samsung Cortex A72&A53'))
# Out:
# AMD

# %%
df['Cpu Brand']=df['Cpu Name'].apply(fache_processor)

# %%
df.head()
# Out:
#   Company   TypeName  ...       Cpu Name      Cpu Brand
# 0   Apple  Ultrabook  ...  Intel Core i5  Intel Core i5
# 1   Apple  Ultrabook  ...  Intel Core i5  Intel Core i5
# 2      HP   Notebook  ...  Intel Core i5  Intel Core i5
# 3   Apple  Ultrabook  ...  Intel Core i7  Intel Core i7
# 4   Apple  Ultrabook  ...  Intel Core i5  Intel Core i5
#
# [5 rows x 14 columns]

# %%
df['Cpu Brand'].value_counts()
# Out:
# Intel Core i7            515
# Intel Core i5            423
# Other Intel Processor    141
# Intel Core i3            134
# AMD                       61
# Name: Cpu Brand, dtype: int64

# %%
df['Cpu Brand'].value_counts().plot(kind='bar')

# %%
sn.barplot(x=df['Cpu Brand'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df.drop(columns=['Cpu','Cpu Name'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram  ... IPS         ppi      Cpu Brand
# 0   Apple  Ultrabook    8  ...   1  226.983005  Intel Core i5
# 1   Apple  Ultrabook    8  ...   0  127.677940  Intel Core i5
# 2      HP   Notebook    8  ...   0  141.211998  Intel Core i5
# 3   Apple  Ultrabook   16  ...   1  220.534624  Intel Core i7
# 4   Apple  Ultrabook    8  ...   1  226.983005  Intel Core i5
#
# [5 rows x 12 columns]

# %%
df['Memory'].value_counts()
# Out:
# 256GB SSD                        412
# 1TB HDD                          215
# 500GB HDD                        123
# 512GB SSD                        114
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         74
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                36
# 2TB HDD                           16
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 64GB Flash Storage                13
# 256GB SSD +  2TB HDD              10
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 1.0TB Hybrid                       7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# ...

# %%
df['Memory']=df['Memory'].str.replace('\.0','')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   """Entry point for launching an IPython kernel.

# %%
df['Memory'].value_counts()
# Out:
# 256GB SSD                        412
# 1TB HDD                          216
# 500GB HDD                        123
# 512GB SSD                        114
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         74
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                36
# 2TB HDD                           16
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 64GB Flash Storage                13
# 256GB SSD +  2TB HDD              10
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 1TB Hybrid                         7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# ...

# %%
df['Memory']=df['Memory'].str.replace('GB','')

# %%
df['Memory'].value_counts()
# Out:
# 256 SSD                        412
# 1TB HDD                        216
# 500 HDD                        123
# 512 SSD                        114
# 128 SSD +  1TB HDD              94
# 128 SSD                         74
# 256 SSD +  1TB HDD              73
# 32 Flash Storage                36
# 2TB HDD                         16
# 512 SSD +  1TB HDD              14
# 1TB SSD                         14
# 64 Flash Storage                13
# 256 SSD +  2TB HDD              10
# 256 Flash Storage                8
# 16 Flash Storage                 7
# 1TB Hybrid                       7
# 32 SSD                           6
# 180 SSD                          5
# 128 Flash Storage                4
# 512 SSD +  2TB HDD               3
# 16 SSD                           3
# 512 Flash Storage                2
# 1TB SSD +  1TB HDD               2
# 256 SSD +  500 HDD               2
# 128 SSD +  2TB HDD               2
# 256 SSD +  256 SSD               2
# 512 SSD +  256 SSD               1
# ...

# %%
df['Memory']=df['Memory'].str.replace('TB','000')

# %%
df['Memory'].value_counts()
# Out:
# 256 SSD                         412
# 1000 HDD                        216
# 500 HDD                         123
# 512 SSD                         114
# 128 SSD +  1000 HDD              94
# 128 SSD                          74
# 256 SSD +  1000 HDD              73
# 32 Flash Storage                 36
# 2000 HDD                         16
# 512 SSD +  1000 HDD              14
# 1000 SSD                         14
# 64 Flash Storage                 13
# 256 SSD +  2000 HDD              10
# 256 Flash Storage                 8
# 16 Flash Storage                  7
# 1000 Hybrid                       7
# 32 SSD                            6
# 180 SSD                           5
# 128 Flash Storage                 4
# 512 SSD +  2000 HDD               3
# 16 SSD                            3
# 512 Flash Storage                 2
# 1000 SSD +  1000 HDD              2
# 256 SSD +  500 HDD                2
# 128 SSD +  2000 HDD               2
# 256 SSD +  256 SSD                2
# ...

# %%
new=df['Memory'].str.split('+',n=1,expand=True)

# %%
new
# Out:
#                       0     1
# 0               128 SSD  None
# 1     128 Flash Storage  None
# 2               256 SSD  None
# 3               512 SSD  None
# 4               256 SSD  None
# ...                 ...   ...
# 1269            500 HDD  None
# 1270            128 SSD  None
# 1271            512 SSD  None
# 1272   64 Flash Storage  None
# 1273           1000 HDD  None
#
# [1274 rows x 2 columns]

# %%
df['first']=new[0]

# %%
df['first'].value_counts()
# Out:
# 256 SSD              412
# 1000 HDD             216
# 500 HDD              123
# 512 SSD              114
# 128 SSD               96
# 256 SSD               88
# 128 SSD               74
# 32 Flash Storage      36
# 512 SSD               20
# 2000 HDD              16
# 1000 SSD              14
# 64 Flash Storage      13
# 256 Flash Storage      8
# 16 Flash Storage       7
# 1000 Hybrid            7
# 32 SSD                 6
# 180 SSD                5
# 128 Flash Storage      4
# 16 SSD                 3
# 1000 SSD               2
# 512 Flash Storage      2
# 64 SSD                 1
# 64 Flash Storage       1
# 1000 HDD               1
# 32 HDD                 1
# 128 HDD                1
# 240 SSD                1
# 8 SSD                  1
# 508 Hybrid             1
# Name: first, dtype: int64

# %%
df['first']=df['first'].str.strip()

# %%
df['1SSD']=df['first'].apply(lambda x : 1 if 'SSD' in x else 0)
df['1HDD']=df['first'].apply(lambda x : 1 if 'HDD' in x else 0)
df['1Hybrid']=df['first'].apply(lambda x : 1 if 'Hybrid' in x else 0)
df['Flash Storage']=df['first'].apply(lambda x : 1 if 'Flash Storage' in x else 0)


df['first']=df['first'].str.replace(r'\D','')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   import sys

# %%
df['second']=new[1]

# %%
df['second'].value_counts()
# Out:
#   1000 HDD       185
#   2000 HDD        15
#   256 SSD          3
#   500 HDD          2
#   1000 Hybrid      2
#   512 SSD          1
# Name: second, dtype: int64

# %%
df['second'].value_counts()
# Out:
#   1000 HDD       185
#   2000 HDD        15
#   256 SSD          3
#   500 HDD          2
#   1000 Hybrid      2
#   512 SSD          1
# Name: second, dtype: int64

# %%
df["second"].fillna("0", inplace = True)

# %%
df['2SSD']=df['second'].apply(lambda x : 1 if 'SSD' in x else 0)
df['2HDD']=df['second'].apply(lambda x : 1 if 'HDD' in x else 0)
df['2Hybrid']=df['second'].apply(lambda x : 1 if 'Hybrid' in x else 0)
df['1Flash Storage']=df['second'].apply(lambda x : 1 if 'Flash Storage' in x else 0)

# %%
df['second']=df['second'].str.replace(r"\D",'')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   """Entry point for launching an IPython kernel.

# %%
df['first']=df['first'].astype(int)

# %%
df['second']=df['second'].astype(int)

# %%
df['SSD']=(df['1SSD']*df['first']+df['2SSD']*df['second'])
df['HDD']=(df['1HDD']*df['first']+df['2HDD']*df['second'])
df['Hybrid']=(df['1Hybrid']*df['first']+df['2Hybrid']*df['second'])
df['Flash Storage']=(df['Flash Storage']*df['first']+df['1Flash Storage']*df['second'])

# %%
df.drop(columns=['1SSD','2SSD','1HDD','2HDD','1Hybrid','2Hybrid','1Flash Storage'],inplace=True)

# %%
df.drop(columns=['first','second','Memory'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram  ...  SSD HDD  Hybrid
# 0   Apple  Ultrabook    8  ...  128   0       0
# 1   Apple  Ultrabook    8  ...    0   0       0
# 2      HP   Notebook    8  ...  256   0       0
# 3   Apple  Ultrabook   16  ...  512   0       0
# 4   Apple  Ultrabook    8  ...  256   0       0
#
# [5 rows x 15 columns]

# %%
df.corr()['Price']
# Out:
# Ram              0.740106
# Weight           0.212192
# Price            1.000000
# Touchscreen      0.188631
# IPS              0.250358
# ppi              0.469539
# Flash Storage   -0.037176
# SSD              0.669957
# HDD             -0.098011
# Hybrid           0.022533
# Name: Price, dtype: float64

# %%
df.drop(columns=['Flash Storage','Hybrid'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram  ...      Cpu Brand  SSD  HDD
# 0   Apple  Ultrabook    8  ...  Intel Core i5  128    0
# 1   Apple  Ultrabook    8  ...  Intel Core i5    0    0
# 2      HP   Notebook    8  ...  Intel Core i5  256    0
# 3   Apple  Ultrabook   16  ...  Intel Core i7  512    0
# 4   Apple  Ultrabook    8  ...  Intel Core i5  256    0
#
# [5 rows x 13 columns]

# %%
df['Gpu'].value_counts().plot(kind='bar')

# %%
df['Gpu'].value_counts()
# Out:
# Intel HD Graphics 620      279
# Intel HD Graphics 520      181
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# AMD Radeon 540               1
# ARM Mali T860 MP4            1
# Name: Gpu, Length: 110, dtype: int64

# %%
df['Gpu']=df['Gpu'].apply(lambda x: x.split()[0])

# %%
df['Gpu'].value_counts()
# Out:
# Intel     703
# Nvidia    396
# AMD       174
# ARM         1
# Name: Gpu, dtype: int64

# %%
df=df[df['Gpu']!='ARM']
df['Gpu'].value_counts()
# Out:
# Intel     703
# Nvidia    396
# AMD       174
# Name: Gpu, dtype: int64

# %%
df['Gpu'].value_counts().plot(kind='bar')

# %%
sn.barplot(x=df['Gpu'],y=df['Price'])

# %%
df.head()
# Out:
#   Company   TypeName  Ram    Gpu  ...         ppi      Cpu Brand  SSD  HDD
# 0   Apple  Ultrabook    8  Intel  ...  226.983005  Intel Core i5  128    0
# 1   Apple  Ultrabook    8  Intel  ...  127.677940  Intel Core i5    0    0
# 2      HP   Notebook    8  Intel  ...  141.211998  Intel Core i5  256    0
# 3   Apple  Ultrabook   16    AMD  ...  220.534624  Intel Core i7  512    0
# 4   Apple  Ultrabook    8  Intel  ...  226.983005  Intel Core i5  256    0
#
# [5 rows x 13 columns]

# %%
df['OpSys'].value_counts().plot(kind='bar')

# %%
df['OpSys'].value_counts()
# Out:
# Windows 10      1047
# No OS             66
# Linux             58
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: OpSys, dtype: int64

# %%
def fache_opsys(opsys):
  if opsys=='Windows 10' or opsys=='Windows 7' or opsys=='Windows 10 S':
    return 'Windows'
  elif opsys=='Mac OS X' or opsys=='macOS':
    return 'Mac'
  else:
    return 'Others/No OS/Linux'

# %%
df['op']=df['OpSys'].apply(fache_opsys)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df.head()
# Out:
#   Company   TypeName  Ram    Gpu  ...      Cpu Brand  SSD  HDD                  op
# 0   Apple  Ultrabook    8  Intel  ...  Intel Core i5  128    0                 Mac
# 1   Apple  Ultrabook    8  Intel  ...  Intel Core i5    0    0                 Mac
# 2      HP   Notebook    8  Intel  ...  Intel Core i5  256    0  Others/No OS/Linux
# 3   Apple  Ultrabook   16    AMD  ...  Intel Core i7  512    0                 Mac
# 4   Apple  Ultrabook    8  Intel  ...  Intel Core i5  256    0                 Mac
#
# [5 rows x 14 columns]

# %%
df.drop(columns=['OpSys'],inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df.head()
# Out:
#   Company   TypeName  Ram    Gpu  ...      Cpu Brand  SSD  HDD                  op
# 0   Apple  Ultrabook    8  Intel  ...  Intel Core i5  128    0                 Mac
# 1   Apple  Ultrabook    8  Intel  ...  Intel Core i5    0    0                 Mac
# 2      HP   Notebook    8  Intel  ...  Intel Core i5  256    0  Others/No OS/Linux
# 3   Apple  Ultrabook   16    AMD  ...  Intel Core i7  512    0                 Mac
# 4   Apple  Ultrabook    8  Intel  ...  Intel Core i5  256    0                 Mac
#
# [5 rows x 13 columns]

# %%
df.corr()['Price']
# Out:
# Ram            0.739996
# Weight         0.211667
# Price          1.000000
# Touchscreen    0.190382
# IPS            0.251514
# ppi            0.471481
# SSD            0.669808
# HDD           -0.098481
# Name: Price, dtype: float64

# %%
sn.barplot(x=df['op'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sn.distplot(df['Weight'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
import numpy as np
sn.distplot(np.log(df['Price']))
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sn.heatmap(df.corr())

# %%
X = df.drop(columns=['Price'])
y = np.log(df['Price'])

# %%
X
# Out:
#      Company            TypeName  Ram  ...  SSD   HDD                  op
# 0      Apple           Ultrabook    8  ...  128     0                 Mac
# 1      Apple           Ultrabook    8  ...    0     0                 Mac
# 2         HP            Notebook    8  ...  256     0  Others/No OS/Linux
# 3      Apple           Ultrabook   16  ...  512     0                 Mac
# 4      Apple           Ultrabook    8  ...  256     0                 Mac
# ...      ...                 ...  ...  ...  ...   ...                 ...
# 1269    Asus            Notebook    4  ...    0   500             Windows
# 1270  Lenovo  2 in 1 Convertible    4  ...  128     0             Windows
# 1271  Lenovo  2 in 1 Convertible   16  ...  512     0             Windows
# 1272  Lenovo            Notebook    2  ...    0     0             Windows
# 1273      HP            Notebook    6  ...    0  1000             Windows
#
# [1273 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1273 entries, 0 to 1273
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Company      1273 non-null   object
#  1   TypeName     1273 non-null   object
#  2   Ram          1273 non-null   int32
#  3   Gpu          1273 non-null   object
#  4   Weight       1273 non-null   float32
#  5   Price        1273 non-null   float64
#  6   Touchscreen  1273 non-null   int64
#  7   IPS          1273 non-null   int64
#  8   ppi          1273 non-null   float64
#  9   Cpu Brand    1273 non-null   object
#  10  SSD          1273 non-null   int64
#  11  HDD          1273 non-null   int64
#  12  op           1273 non-null   object
# dtypes: float32(1), float64(2), int32(1), int64(4), object(5)
# memory usage: 161.6+ KB

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.15,random_state=2)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score,mean_absolute_error
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,AdaBoostRegressor,ExtraTreesRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor

# %% [markdown]
# Linear regression

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,3,8,11])
],remainder='passthrough')

step2 = LinearRegression()

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.7831567115450269
# MAE 0.22167696491054756

# %% [markdown]
# Ridge Regression

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,3,8,11])
],remainder='passthrough')

step2 = Ridge(alpha=10)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.7954034359736726
# MAE 0.2181888482563727

# %% [markdown]
# Lasso Regression

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,3,8,11])
],remainder='passthrough')

step2 = Lasso(alpha=0.001)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.7930768350673781
# MAE 0.2187453457353036

# %% [markdown]
# KNN

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,3,8,11])
],remainder='passthrough')

step2 = KNeighborsRegressor(n_neighbors=3)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.7476333840665237
# MAE 0.21419896970420968

# %% [markdown]
# Decision Tree

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,3,8,11])
],remainder='passthrough')

step2 = DecisionTreeRegressor(max_depth=8)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8113300985243329
# MAE 0.20303103983873985

# %% [markdown]
# SVM

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,3,8,11])
],remainder='passthrough')

step2 = SVR(kernel='rbf',C=10000,epsilon=0.1)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8239360292059622
# MAE 0.20198244295992607

# %% [markdown]
# Random Forest

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,3,8,11])
],remainder='passthrough')

step2 = RandomForestRegressor(n_estimators=100,
                              random_state=3,
                              max_samples=0.5,
                              max_features=0.75,
                              max_depth=15)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8499566520676529
# MAE 0.1797758308549372

# %%
import pickle

pickle.dump(df,open('/content/drice/MyDrive/laptop_price_prediction/df.pkl','wb'))
pickle.dump(pipe,open('/content/drice/MyDrive/laptop_price_prediction/pipe.pkl','wb'))

# %% [markdown]
# AdaBoost

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,3,8,11])
],remainder='passthrough')

step2 = AdaBoostRegressor(n_estimators=15,learning_rate=1.0)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.7848273784545964
# MAE 0.22673221836279903

# %% [markdown]
# Gradient Boost

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,3,8,11])
],remainder='passthrough')

step2 = GradientBoostingRegressor(n_estimators=500)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8458528035784753
# MAE 0.17444647551697956

# %% [markdown]
# XgBoost

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,3,8,11])
],remainder='passthrough')

step2 = XGBRegressor(n_estimators=45,max_depth=5,learning_rate=0.5)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# [18:21:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# R2 score 0.8728680414721783
# MAE 0.16774693663306275

# %% [markdown]
# Stacking

# %%
from sklearn.ensemble import VotingRegressor,StackingRegressor

step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,3,8,11])
],remainder='passthrough')


estimators = [
    ('rf', RandomForestRegressor(n_estimators=350,random_state=3,max_samples=0.5,max_features=0.75,max_depth=15)),
    ('gbdt',GradientBoostingRegressor(n_estimators=100,max_features=0.5)),
    ('xgb', XGBRegressor(n_estimators=25,learning_rate=0.3,max_depth=5))
]

step2 = StackingRegressor(estimators=estimators, final_estimator=Ridge(alpha=100))

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# [18:25:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:25:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:25:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:25:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:25:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:25:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# R2 score 0.8548112482704314
# MAE 0.1823110591201728

# %%
df.head()
# Out:
#   Company   TypeName  Ram    Gpu  ...      Cpu Brand  SSD  HDD                  op
# 0   Apple  Ultrabook    8  Intel  ...  Intel Core i5  128    0                 Mac
# 1   Apple  Ultrabook    8  Intel  ...  Intel Core i5    0    0                 Mac
# 2      HP   Notebook    8  Intel  ...  Intel Core i5  256    0  Others/No OS/Linux
# 3   Apple  Ultrabook   16    AMD  ...  Intel Core i7  512    0                 Mac
# 4   Apple  Ultrabook    8  Intel  ...  Intel Core i5  256    0                 Mac
#
# [5 rows x 13 columns]

# %%
df['Company'].unique()
# Out:
# array(['Apple', 'HP', 'Acer', 'Asus', 'Dell', 'Lenovo', 'Chuwi', 'MSI',
#        'Microsoft', 'Toshiba', 'Huawei', 'Xiaomi', 'Vero', 'Razer',
#        'Mediacom', 'Samsung', 'Google', 'Fujitsu', 'LG'], dtype=object)

# %%
df['Ram'].unique()
# Out:
# array([ 8, 16,  4,  2, 12,  6, 32, 24, 64], dtype=int32)
